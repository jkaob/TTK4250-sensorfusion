# %%
#import perform_mixture_reduction
# %run perform_mixture_reduction.py
# Out:
# [0.   1.25 1.25]
# [1.625  3.1875 3.8125]

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %run run_imm.py
# Out:
# matplotlib backend: module://ipykernel.pylab.backend_inline
# matplotlib config file: c:\users\jeg_j\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# matplotlib config dir: C:\SPB_Data\.matplotlib
# 'science' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles
# setting grid and only grid and legend manually
# lower bound:  168.27855443662838
# upper bound:  233.99426889232492
# ANIS=[2.24131596 2.23729835] with CIANIS=[1.68278554 2.33994269]
# ANIS=1.8685055253073493 with CIANIS=[1.68278554 2.33994269]
# ANIS=1.8685055253073493 and CIANIS=[1.68278554 2.33994269]
# ANEES_upd=11.346363327115697, ANEES_pred=10.911489242024798 and CIANEES=[3.54640974 4.47632468]
